# %%
#Universidad del Valle de Guatemala
#Angel Esquit - 23221
#Javier Chávez - 23132
#Ejercicio 5

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
movies = pd.read_csv("movies2023-1.csv", engine = "python")

# %% [markdown]
# #Opción 5: Cantidad de películas por año de lanzamiento

# %%
def peli_años():
    df_infoP = movies
    años = df_infoP["startYear"].value_counts()
    return pd.DataFrame(años)
peli_años()

# %% [markdown]
# #Opción 6: Gráfico de barras

# %%
def grafico():
    df_infoP = movies
    años = df_infoP["startYear"].value_counts().head(18)
    plt.figure(figsize=(15, 6))
    plt.bar(años.index.astype(str), años.values)
    plt.xlabel('Años')
    plt.ylabel('Conteos')
    plt.title('Gráfica de conteos por año')
    plt.show()
grafico()

# %% [markdown]
# #Opción 7: Películas más votadas

# %%
def mas_votos():
    n = int(input("¿Cuántas películas deseea observar?"))
    df_infoP = movies
    df_infoP = df_infoP.sort_values(by = "numVotes", ascending = False)
    return df_infoP.head(n)
mas_votos()
# Out:
#           tconst                                   primaryTitle titleType
# 20621  tt0468569                                The Dark Knight     movie  \
# 26302  tt0133093                                     The Matrix     movie
# 25617  tt0167260  The Lord of the Rings: The Return of the King     movie
# 25616  tt0167261          The Lord of the Rings: The Two Towers     movie
# 13417  tt0102926                       The Silence of the Lambs     movie
# 67     tt0499549                                         Avatar     movie
# 390    tt0088763                             Back to the Future     movie
# 69     tt0120338                                        Titanic     movie
# 12887  tt2015381                        Guardians of the Galaxy     movie
# 36169  tt4154796                              Avengers: Endgame     movie
#
#        startYear  runtimeMinutes principalGenre  averageRating   numVotes
# 20621     2008.0           152.0         Action            9.0  2706445.0  \
# 26302     1999.0           136.0         Action            8.7  1949993.0
# 25617     2003.0           201.0         Action            9.0  1880210.0
# 25616     2002.0           179.0         Action            8.8  1697355.0
# 13417     1991.0           118.0          Crime            8.6  1461624.0
# 67        2009.0           162.0         Action            7.9  1338445.0
# 390       1985.0           116.0      Adventure            8.5  1232746.0
# 69        1997.0           194.0          Drama            7.9  1215194.0
# 12887     2014.0           121.0         Action            8.0  1202144.0
# 36169     2019.0           181.0         Action            8.4  1170959.0
#
#       region     directorName  directorBirthYear  directorDeathYear
# 20621     US              NaN                NaN                NaN  \
# 26302     US   Lana Wachowski             1965.0                NaN
# 25617     US    Peter Jackson             1961.0                NaN
# 25616     US    Peter Jackson             1961.0                NaN
# 13417     US   Jonathan Demme             1944.0             2017.0
# 67        US              NaN                NaN                NaN
# 390       US  Robert Zemeckis             1952.0                NaN
# 69        US              NaN                NaN                NaN
# 12887     US              NaN                NaN                NaN
# 36169     US              NaN                NaN                NaN
#
#             writerName  writerBirthYear  writerDeathYear
# 20621              NaN              NaN              NaN  \
# 26302  Lilly Wachowski           1967.0              NaN
# 25617              NaN              NaN              NaN
# 25616              NaN              NaN              NaN
# 13417    Thomas Harris           1940.0              NaN
# 67                 NaN              NaN              NaN
# 390    Robert Zemeckis           1952.0              NaN
# 69                 NaN              NaN              NaN
# 12887              NaN              NaN              NaN
# 36169              NaN              NaN              NaN
#
#       director1stProfession director2ndProfession director3rdProfession
# 20621               unknown               unknown               unknown  \
# 26302                writer              producer              director
# 25617              producer              director                writer
# 25616              producer              director                writer
# 13417              director              producer                writer
# 67                  unknown               unknown               unknown
# 390                producer                writer              director
# 69                  unknown               unknown               unknown
# 12887               unknown               unknown               unknown
# 36169               unknown               unknown               unknown
#
#       writer1stProfession writer2ndProfession writer3rdProfession
# 20621             unknown             unknown             unknown  \
# 26302              writer            producer            director
# 25617             unknown             unknown             unknown
# 25616             unknown             unknown             unknown
# 13417              writer                 NaN                 NaN
# 67                unknown             unknown             unknown
# 390              producer              writer            director
# 69                unknown             unknown             unknown
# 12887             unknown             unknown             unknown
# 36169             unknown             unknown             unknown
#
#                          genres        types
# 20621        Action,Crime,Drama  imdbDisplay
# 26302             Action,Sci-Fi  imdbDisplay
# 25617    Action,Adventure,Drama      unknown
# 25616    Action,Adventure,Drama      unknown
# 13417      Crime,Drama,Thriller      unknown
# 67     Action,Adventure,Fantasy  alternative
# 390     Adventure,Comedy,Sci-Fi  imdbDisplay
# 69                Drama,Romance      unknown
# 12887   Action,Adventure,Comedy  imdbDisplay
# 36169    Action,Adventure,Drama      unknown

# %% [markdown]
# #Opción 8:  Películas por director específico

# %%
def director_espec():
    director = input("¿Las películas de qué director desea observar?")
    directores = movies["directorName"].unique()
    if director in directores:
        df_infoP = movies[movies["directorName"] == director]
        return df_infoP
    else:
        print("El director ingresado no existe.")
director_espec()
# Out:
#           tconst                                   primaryTitle titleType
# 24236  tt0103873                                     Dead Alive     movie  \
# 25616  tt0167261          The Lord of the Rings: The Two Towers     movie
# 25617  tt0167260  The Lord of the Rings: The Return of the King     movie
# 26450  tt0380510                               The Lovely Bones     movie
#
#        startYear  runtimeMinutes principalGenre  averageRating   numVotes
# 24236     1992.0           104.0         Comedy            7.5    99773.0  \
# 25616     2002.0           179.0         Action            8.8  1697355.0
# 25617     2003.0           201.0         Action            9.0  1880210.0
# 26450     2009.0           135.0          Drama            6.6   173480.0
#
#       region   directorName  directorBirthYear  directorDeathYear
# 24236     US  Peter Jackson             1961.0                NaN  \
# 25616     US  Peter Jackson             1961.0                NaN
# 25617     US  Peter Jackson             1961.0                NaN
# 26450     US  Peter Jackson             1961.0                NaN
#
#              writerName  writerBirthYear  writerDeathYear
# 24236  Stephen Sinclair              NaN              NaN  \
# 25616               NaN              NaN              NaN
# 25617               NaN              NaN              NaN
# 26450        Fran Walsh           1959.0              NaN
#
#       director1stProfession director2ndProfession director3rdProfession
# 24236              producer              director                writer  \
# 25616              producer              director                writer
# 25617              producer              director                writer
# 26450              producer              director                writer
#
#       writer1stProfession writer2ndProfession writer3rdProfession
# 24236              writer            director               actor  \
# 25616             unknown             unknown             unknown
# 25617             unknown             unknown             unknown
# 26450              writer  casting_department            producer
#
#                        genres        types
# 24236   Comedy,Fantasy,Horror  imdbDisplay
# 25616  Action,Adventure,Drama      unknown
# 25617  Action,Adventure,Drama      unknown
# 26450  Drama,Fantasy,Thriller  imdbDisplay

# %% [markdown]
# #Opción 9: Directores que tienen una mayor cantidad de películas

# %%
def masP_directores():
    n = int(input("¿Cuántas películas deseea observar?"))
    df_infoP = movies
    df_infoP = df_infoP["directorName"].value_counts()
    return df_infoP.head(n)
masP_directores()
# Out:
# directorName
# Allan Dwan                           94
# D.W. Griffith                        88
# Georges Méliès                       81
# Bud Fisher                           76
# Seymour Kneitel                      71
# Chuck Jones                          71
# Jules White                          65
# William Beaudine                     60
# Phillips Smalley                     59
# Gilbert M. Broncho Billy Anderson    52
# Alorangel                            49
# Edwin S. Porter                      46
# Jack Eaton                           43
# Connie Rasinski                      43
# Charles Lamont                       43
# James W. Horne                       41
# Lesley Selander                      39
# Al Christie                          38
# B. Reeves Eason                      38
# Roy Mack                             37
# Name: count, dtype: int64

# %% [markdown]
# #Opción 10: Directores que su principal profesión es diferente de "director"

# %%
def director_prof():
    df_infoP = movies
    df_infoP = df_infoP[movies["director1stProfession"] != "director"]
    directores = df_infoP["directorName"].dropna().unique()
    return pd.DataFrame(directores, columns = ["directorName"])
director_prof().head(5)
# Out:
#        directorName
# 0    Ingmar Bergman
# 1       Liv Ullmann
# 2  Federico Fellini
# 3     Buster Keaton
# 4    Clyde Bruckman
